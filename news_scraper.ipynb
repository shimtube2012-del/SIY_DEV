# %% [markdown]
# # 기업은행 뉴스 스크래핑
# 이 노트북은 '기업은행'이 포함된 뉴스를 수집합니다.

# %%
# 필요한 라이브러리 설치 (처음 한 번만 실행)
# !python -m pip install requests beautifulsoup4 pandas lxml feedparser

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime
import time
import feedparser
import urllib.parse

# %%
def search_google_news(keyword, display=10):
    """
    Google News RSS에서 뉴스 수집
    keyword: 검색 키워드
    display: 가져올 뉴스 개수
    """
    news_list = []
    
    try:
        encoded_keyword = urllib.parse.quote(keyword)
        rss_url = f"https://news.google.com/rss/search?q={encoded_keyword}&hl=ko&gl=KR&ceid=KR:ko"
        
        print(f"[Google News] RSS URL: {rss_url}")
        print("뉴스를 가져오는 중...")
        
        feed = feedparser.parse(rss_url)
        
        if not feed.entries:
            print("[Google News] RSS에서 뉴스를 찾을 수 없습니다.")
            return []
        
        print(f"✓ [Google News] {len(feed.entries)}개의 뉴스를 찾았습니다!")
        
        for idx, entry in enumerate(feed.entries[:display]):
            try:
                title = entry.get('title', '제목 없음')
                link = entry.get('link', '')
                pub_date = entry.get('published', '날짜 정보 없음')
                summary = entry.get('summary', '요약 없음')
                source = entry.get('source', {}).get('title', '언론사 정보 없음')
                
                if summary and summary != '요약 없음':
                    summary_soup = BeautifulSoup(summary, 'html.parser')
                    summary = summary_soup.get_text(strip=True)
                
                news_list.append({
                    '번호': idx + 1,
                    '제목': title,
                    '언론사': source,
                    '날짜': pub_date,
                    '요약': summary[:200] if len(summary) > 200 else summary,
                    '링크': link,
                    '출처': 'Google News'
                })
            except Exception as e:
                print(f"항목 {idx + 1} 파싱 오류: {e}")
                continue
        
        return news_list
    
    except Exception as e:
        print(f"[Google News] 뉴스 수집 오류: {e}")
        import traceback
        traceback.print_exc()
        return []


def search_naver_news(keyword, display=10):
    """
    네이버 뉴스 검색 (모바일 웹 스크래핑)
    keyword: 검색 키워드
    display: 가져올 뉴스 개수
    """
    news_list = []
    
    try:
        encoded_keyword = urllib.parse.quote(keyword)
        # 모바일 네이버 뉴스 검색 URL (날짜순 정렬)
        url = f"https://m.search.naver.com/search.naver?where=m_news&query={encoded_keyword}&sort=1"
        
        print(f"[네이버 뉴스] URL: {url}")
        print("뉴스를 가져오는 중...")
        
        headers = {
            'User-Agent': 'Mozilla/5.0 (iPhone; CPU iPhone OS 14_0 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/14.0 Mobile/15E148 Safari/604.1'
        }
        
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # 모바일 네이버 뉴스 검색 결과 파싱 (FDS 디자인 시스템)
        news_container = soup.select_one('div.fds-news-item-list-tab')
        
        if not news_container:
            print("[네이버 뉴스] 뉴스 컨테이너를 찾을 수 없습니다.")
            return []
        
        # 뉴스 아이템들 - 직접 자식만 선택 (중첩 방지)
        news_items = news_container.find_all('div', class_='sds-comps-vertical-layout', recursive=False)
        
        if not news_items:
            print("[네이버 뉴스] 뉴스를 찾을 수 없습니다.")
            return []
        
        print(f"✓ [네이버 뉴스] {len(news_items)}개의 뉴스를 찾았습니다!")
        
        seen_links = set()  # 중복 링크 체크용
        count = 0
        
        for item in news_items:
            if count >= display:
                break
            
            try:
                # 뉴스 링크들 찾기
                links = item.find_all('a', href=True)
                
                title = None
                link = None
                summary = None
                source = None
                pub_date = None
                
                for a_tag in links:
                    href = a_tag.get('href', '')
                    text = a_tag.get_text(strip=True)
                    
                    # Keep 버튼, 빈 링크 제외
                    if 'keep.naver.com' in href or href == '#' or not text:
                        continue
                    
                    # 뉴스 링크 찾기 (20자 이상의 텍스트)
                    if ('news.naver.com' in href or href.startswith('http')) and len(text) > 20:
                        if title is None:
                            title = text
                            link = href
                        elif summary is None and text != title:
                            summary = text
                
                # 제목이나 링크가 없거나 중복이면 건너뛰기
                if not title or not link or link in seen_links:
                    continue
                
                seen_links.add(link)
                
                # span 태그에서 언론사, 날짜 추출
                spans = item.find_all('span')
                seen_texts = set()
                
                for span in spans:
                    text = span.get_text(strip=True)
                    if not text or text in seen_texts or len(text) > 30:
                        continue
                    seen_texts.add(text)
                    
                    # 시간 패턴 (X분 전, X시간 전, X일 전)
                    if '전' in text and any(c.isdigit() for c in text):
                        if pub_date is None:
                            pub_date = text
                    # 언론사 (시간이 아니고, 제목과 다른 짧은 텍스트)
                    elif source is None and len(text) > 1 and text not in title:
                        source = text
                
                news_list.append({
                    '번호': count + 1,
                    '제목': title,
                    '언론사': source or '언론사 정보 없음',
                    '날짜': pub_date or '날짜 정보 없음',
                    '요약': (summary[:200] if summary and len(summary) > 200 else summary) or '요약 없음',
                    '링크': link,
                    '출처': '네이버 뉴스'
                })
                count += 1
                
            except Exception as e:
                print(f"항목 파싱 오류: {e}")
                continue
        
        return news_list
    
    except Exception as e:
        print(f"[네이버 뉴스] 뉴스 수집 오류: {e}")
        import traceback
        traceback.print_exc()
        return []


def search_all_news(keyword, display_per_source=10):
    """
    모든 소스(Google News, 네이버)에서 뉴스 수집
    keyword: 검색 키워드
    display_per_source: 각 소스별 가져올 뉴스 개수
    """
    all_news = []
    
    print("=" * 60)
    print(f"'{keyword}' 키워드로 뉴스를 검색합니다...")
    print("=" * 60)
    
    # Google News 검색
    print("\n[1/2] Google News 검색 중...")
    google_news = search_google_news(keyword, display_per_source)
    all_news.extend(google_news)
    
    time.sleep(1)  # 요청 간격 조절
    
    # 네이버 뉴스 검색
    print("\n[2/2] 네이버 뉴스 검색 중...")
    naver_news = search_naver_news(keyword, display_per_source)
    all_news.extend(naver_news)
    
    # 번호 재정렬
    for idx, news in enumerate(all_news):
        news['번호'] = idx + 1
    
    print("\n" + "=" * 60)
    print(f"총 {len(all_news)}개의 뉴스 수집 완료!")
    print(f"  - Google News: {len(google_news)}개")
    print(f"  - 네이버 뉴스: {len(naver_news)}개")
    print("=" * 60)
    
    return all_news

# %%
# 기업은행 은행장 뉴스 검색 (Google + 네이버)
print("'기업은행 은행장' 뉴스를 검색합니다...\n")
news_data = search_all_news("기업은행 은행장", display_per_source=10)

if news_data:
    print(f"\n총 {len(news_data)}개의 뉴스를 찾았습니다.\n")
    
    # 데이터프레임으로 변환
    df = pd.DataFrame(news_data)
    
    # 결과 출력
    print("=" * 80)
    for idx, row in df.iterrows():
        print(f"\n[{row['번호']}] [{row['출처']}] {row['제목']}")
        print(f"언론사: {row['언론사']} | 날짜: {row['날짜']}")
        print(f"요약: {row['요약'][:100]}...")
        print(f"링크: {row['링크']}")
        print("-" * 80)
else:
    print("뉴스를 찾을 수 없습니다.")
# Out:
# '기업은행 은행장' 뉴스를 검색합니다...
#
# ============================================================
# '기업은행 은행장' 키워드로 뉴스를 검색합니다...
# ============================================================
#
# [1/2] Google News 검색 중...
# [Google News] RSS URL: https://news.google.com/rss/search?q=%EA%B8%B0%EC%97%85%EC%9D%80%ED%96%89%20%EC%9D%80%ED%96%89%EC%9E%A5&hl=ko&gl=KR&ceid=KR:ko
# 뉴스를 가져오는 중...
# ✓ [Google News] 100개의 뉴스를 찾았습니다!
#
# [2/2] 네이버 뉴스 검색 중...
# [네이버 뉴스] URL: https://m.search.naver.com/search.naver?where=m_news&query=%EA%B8%B0%EC%97%85%EC%9D%80%ED%96%89%20%EC%9D%80%ED%96%89%EC%9E%A5&sort=1
# 뉴스를 가져오는 중...
# ✓ [네이버 뉴스] 15개의 뉴스를 찾았습니다!
#
# ============================================================
# 총 20개의 뉴스 수집 완료!
#   - Google News: 10개
#   - 네이버 뉴스: 10개
# ============================================================
#
# 총 20개의 뉴스를 찾았습니다.
#
# ================================================================================
#
# [1] [Google News] 기업은행, 생산적 금융 발맞춘 조직개편 변화 주목 - fetv.co.kr
# 언론사: fetv.co.kr | 날짜: Sun, 18 Jan 2026 23:00:19 GMT
# 요약: 기업은행, 생산적 금융 발맞춘 조직개편 변화 주목fetv.co.kr...
# 링크: https://news.google.com/rss/articles/CBMiX0FVX3lxTE01SzZ1NkxSaXNxM2U2bFdSU3JET1Z2OW5kWUpiZDJSY2tEd0Q2dkJzYXVzYktSQk5MZjdkb2NybVdrRnN6VkpGbWxjR29hXzczRnZIS2xLdlZTU0RrOXRV?oc=5
# --------------------------------------------------------------------------------
#
# [2] [Google News] 기업은행장 인선 시계 멈췄나…후속 임원인사도 늦어져 '내부 불만' - 블로터
# 언론사: 블로터 | 날짜: Thu, 15 Jan 2026 05:35:30 GMT
# 요약: 기업은행장 인선 시계 멈췄나…후속 임원인사도 늦어져 '내부 불만'블로터...
# 링크: https://news.google.?oc=5
# --------------------------------------------------------------------------------
#
# [3] [Google News] 김성태 기업은행장 퇴임…후임 없이 직무대행 체제로 - 인베스트조선
# 언론사: 인베스트조선 | 날짜: Fri, 02 Jan 2026 08:00:00 GMT
# 요약: 김성태 기업은행장 퇴임…후임 없이 직무대행 체제로인베스트조선...
# 링크: https://news.google.com/rss/articles/CBMigwFBVV95cUxQNGZ1RmVTY0dpNmJOWmdnN1ZWaFNxaG9KdDk3ZFUwMXpJU2pFV0RIaGx5SGFaR0tXRFlRckRuNFJSMzAtZGhya3FJWUZQTURhcWFleXJJRXBtUGRJdjduZzFDYVNLY0hIeEpjcW9BOGNlajB0RUJhbVdlZ0RkUzBZYlhZTQ?oc=5
# --------------------------------------------------------------------------------
#
# [4] [Google News] '안갯속' IBK기업은행 차기 행장 인선…내부 출신 이어갈까 - 디지털투데이
# 언론사: 디지털투데이 | 날짜: Mon, 29 Dec 2025 08:00:00 GMT
# 요약: '안갯속' IBK기업은행 차기 행장 인선…내부 출신 이어갈까디지털투데이...
# 링크: https://news.google.com/rss/articles/CBMic0FVX3lxTE10SUUyNGRUaVRmRmc0YWFtX2tBRWttVGU3dWFNcldfSzUwcnRldWJGQWhPb2I1c2FFa2lYMlV6NWlYVTladUI3NklKNHJXbERhelMzZTRONUpmUVAxdGhGQkpvUVBkdktIYmh6Y0Q4NWVuYmc?oc=5
# --------------------------------------------------------------------------------
#
# [5] [Google News] IBK기업은행, 행장 퇴임 후 직무대행 체제로 - 연합인포맥스
# 언론사: 연합인포맥스 | 날짜: Mon, 05 Jan 2026 08:00:00 GMT
# 요약: IBK기업은행, 행장 퇴임 후 직무대행 체제로연합인포맥스...
# 링크: https://news.google.com/rss/articles/CBMicEFVX3lxTE5oZ2J0OFJqb01YYWhxci16NHJ5d2pVcWVQc2RWdmFPR0VsaWZBb19uc243QWdrcFZKbWFEMmFhV0NJc28xVFA1Y2tlSGdoVzJQaFpIWlY0czNRcU5iaTlyT2xRQXE1Nm4yb1ozVS1GUVQ?oc=5
# --------------------------------------------------------------------------------
#
# [6] [Google News] 김성태 기업은행장 퇴임…직무대행 체제 전환 - 마켓인
# 언론사: 마켓인 | 날짜: Fri, 02 Jan 2026 08:00:00 GMT
# 요약: 김성태 기업은행장 퇴임…직무대행 체제 전환마켓인...
# 링크: https://news.google.com/rss/articles/CBMic0FVX3lxTE5qRHdzNTljVFgwaGRIeG1YbG9IUkFRQm1tNU9YR3hSR2JRQkNhcjlmTU5PWE1VY3l0S1dwNjZIdVRvLXBkaVpxcTFsdUNSTE1YNlhCbWk4U3lYU2pycEZmYXduRWM1WGwySHJ0OHhUd2NpYTA?oc=5
# --------------------------------------------------------------------------------
#
# [7] [Google News] 기업은행, 올해 상반기에도 부행장 인사 순연되나 - 톱데일리
# 언론사: 톱데일리 | 날짜: Thu, 08 Jan 2026 08:00:00 GMT
# 요약: 기업은행, 올해 상반기에도 부행장 인사 순연되나톱데일리...
# 링크: https://news.google.com/rss/articles/CBMiUEFVX3lxTE5rREVIcEpCdTkwZVNxWGhla0xDUzAtV08xcjFUdG4zUkRlNEZDc05hcXZFa2Z6TU1lSkpHTUxpZDRkMGVnYjVkQU5VaFM2ODdr?oc=5
# --------------------------------------------------------------------------------
#
# [8] [Google News] 기업은행, 김형일 전무 은행장 대행 체제로 - 지디넷코리아
# 언론사: 지디넷코리아 | 날짜: Mon, 05 Jan 2026 08:00:00 GMT
# 요약: 기업은행, 김형일 전무 은행장 대행 체제로지디넷코리아...
# 링크: https://news.google.com/rss/articles/CBMiVkFVX3lxTE16bkJHYlJqV2p6WjZZV1J5VjZzVFVkQU5CZGk1a0pLNjNKTVJ4YkFYWmRIZ0dZMEttTzRFRXBBcjVxV3dPcXEyXzFDM0hmcW9lR2diS3Z3?oc=5
# --------------------------------------------------------------------------------
#
# [9] [Google News] IBK기업은행, 행장 공석 장기화…노사 과제·경영 구상도 제자리 - 뉴스투데이
# 언론사: 뉴스투데이 | 날짜: Thu, 15 Jan 2026 23:18:00 GMT
# 요약: IBK기업은행, 행장 공석 장기화…노사 과제·경영 구상도 제자리뉴스투데이...
# 링크: https://news.google.com/rss/articles/CBMiXkFVX3lxTE4yZ25McVhUeURFT2xZZGpQaERrSjdNVFZGR3lOalMtUnhUV1pxSVNvVlFTVWVvUUo5MDR0TF95LVI5aXd0aFE0REpxZUVQNEY4Q1F4OWJCQXVtY0ZzTXc?oc=5
# --------------------------------------------------------------------------------
#
# [10] [Google News] 차기 기업은행장 인사 임박···내부 출신 임명될까 - 시사저널e
# 언론사: 시사저널e | 날짜: Tue, 16 Dec 2025 08:00:00 GMT
# 요약: 차기 기업은행장 인사 임박···내부 출신 임명될까시사저널e...
# 링크: https://news.google.?oc=5
# --------------------------------------------------------------------------------
#
# [11] [네이버 뉴스] 기업은행, 생산적 금융 발맞춘 조직개편 변화 주목
# 언론사: FETV | 날짜: 1시간 전
# 요약: 다만 현재기업은행은은행장인선이 늦어지고 있다. 이 때문에 이후 실시될 임원 인사와 조직개편 등도 지연될 수 있다는 관측도 나온다. 실제 당장기업은행의 생산적 금융 TF 단장을 맡고...
# 링크: https://www.fetv.co.kr/mobile/article.html?no=210071
# --------------------------------------------------------------------------------
#
# [12] [네이버 뉴스] IBK기업은행, 행장 공백·부당대출·노조 갈등 '삼중 부담'… 차기 수장 향배 주목
# 언론사: 일요서울 | 날짜: 1시간 전
# 요약: - 내부통제 강화·노사 현안 동시 부담 - 임명 절차 특성상 인선 일정 불확실 지난 15일 금융권에 따르면 김성태 전기업은행장은 지난 2일 임기를 마치고 퇴임했다. 이후기업은행은 ...
# 링크: https://www.ilyoseoul.co.kr/news/articleView.html?idxno=511846
# --------------------------------------------------------------------------------
#
# [13] [네이버 뉴스] 기은 노조 "청와대·금융위, 보상 문제 해결 즉각 이행하라"
# 언론사: 세이프타임즈 | 날짜: 3일 전
# 요약: 먼저 노조는 "이 대통령이 지난해 금융위원회 업무보고에서기업은행문제 해결을 공식 지시했음에도 불구하고 한 달 가까이 금융위와 관계 당국의 후속 조치가 없다"며 대통령 공약과 지시사...
# 링크: https://www.safetimes.co.kr/news/articleView.html?idxno=238456
# --------------------------------------------------------------------------------
#
# [14] [네이버 뉴스] [금융업계기상도]신한은행‘맑음’·IBK기업은행‘흐림’
# 언론사: NSP통신 | 날짜: 3일 전
# 요약: ◆IBK기업은행‘흐림’= 744억원 규모의 불법 대출을 승인하고 금품을 수수한 혐의를 받는기업은행전·현직 임직원 10명이 재판에 넘겨졌다. 한편 김성태 전기업은행장퇴임 이후 수장 ...
# 링크: https://m.nspna.com/news/?mode=view&newsid=798043
# --------------------------------------------------------------------------------
#
# [15] [네이버 뉴스] 밀린 수당 못받아 뿔난기업은행노조, 총파업 의결ㆍ정치권과 함께 문제해결 성토
# 언론사: 굿모닝경제 | 날짜: 3일 전
# 요약: 이어 "이 문제는기업은행노동자만의 문제가 아니기 때문에 하루빨리 정부와 관계 부처는 해법을 마련하고 문제 해결에 적극적으로 나서기 바란다"며 "공석인은행장도 하루빨리 임명해서 이 ...
# 링크: https://www.goodkyung.com/news/articleView.html?idxno=280929
# --------------------------------------------------------------------------------
#
# [16] [네이버 뉴스] 박홍배 “금융위, 망신당했다고 감정 대응? 의심”
# 언론사: 스카이데일리 | 날짜: 3일 전
# 요약: 또한 “청와대는 단 하루도 더 늦추지 말고 공석인기업은행장을 임명해야 한다”고 말했다. 류장희기업은행노조위원장은 “이재명 대통령이 지난해 12월19일 업무보고에서기업은행문제 해결을...
# 링크: https://m.skyedaily.com/news_view.html?ID=295786
# --------------------------------------------------------------------------------
#
# [17] [네이버 뉴스] 기업은행노조 "대통령 지시 후속조치 없다"…국회서 즉각 이행 촉구
# 언론사: 더팩트 | 날짜: 3일 전
# 요약: 한편, 김성태 전기업은행장의 임기가 지난 2일로 끝났으나기업은행은 김형일 전무 대행 체제를 이어가고 있다. 김인태 부행장과 유일광 부행장의 임기도 곧 만료된다.기업은행노조는 국회 ...
# 링크: https://n.news.naver.com/article/629/0000463410?sid=101
# --------------------------------------------------------------------------------
#
# [18] [네이버 뉴스] 기업은행노조 "행장 조속 임명해야…총인건비 해결 촉구"
# 언론사: 머니투데이방송 | 날짜: 3일 전
# 요약: 기업은행노동조합이 장기 공석 사태인은행장의 조속한 임명을 촉구했습니다.기업은행노조는 국회에서 기자회견을 열어,기업은행장을 임명하고 총액인건비로 인한 시간 외 수당 미지급 문제를 해...
# 링크: https://news.mtn.co.kr/news-detail/2026011617101555550
# --------------------------------------------------------------------------------
#
# [19] [네이버 뉴스] 퍼블릭뉴스통신(public news-network for TTL)
# 언론사: 언론사 정보 없음 | 날짜: 3일 전
# 요약: 기업은행노조 "문제 해결은 대통령 지시...총액인건비제 폐지해야"...
# 링크: https://www.ttlnews.com/
# --------------------------------------------------------------------------------
#
# [20] [네이버 뉴스] 기업은행노조, "기업은행문제해결은 대통령 지시...청, 즉각 이행해야"
# 언론사: 더페어 | 날짜: 3일 전
# 요약: 당시에도 '기업은행의 특수성을 인정하고 인력과 예산의 자율성을 높인다'고 협약했던 만큼, 집권 세력이 책임 있게 나서야 한다"고 주장했다. 둘째는 차기은행장임명 지연과 노사 분쟁 ...
# 링크: https://www.thefairnews.co.kr/news/articleView.html?idxno=66811
# --------------------------------------------------------------------------------

# %%
# 데이터프레임 확인
if news_data:
    df

# %%
# CSV 파일로 저장
if news_data:
    filename = f"기업은행_뉴스_{datetime.now().strftime('%Y%m%d_%H%M%S')}.csv"
    df.to_csv(filename, index=False, encoding='utf-8-sig')
    print(f"\n뉴스 데이터를 '{filename}' 파일로 저장했습니다.")
# Out:
# 뉴스 데이터를 '기업은행_뉴스_20260119_092218.csv' 파일로 저장했습니다.

# %%
# 추가: 특정 키워드로 필터링
if news_data:
    search_keyword = input("추가로 필터링할 키워드를 입력하세요 (Enter로 건너뛰기): ")
    
    if search_keyword:
        filtered_df = df[df['제목'].str.contains(search_keyword) | df['요약'].str.contains(search_keyword)]
        print(f"\n'{search_keyword}' 키워드로 필터링된 결과: {len(filtered_df)}개")
        filtered_df
# Out:
# '은행장' 키워드로 필터링된 결과: 14개
